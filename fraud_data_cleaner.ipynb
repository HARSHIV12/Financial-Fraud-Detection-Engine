# %%
import pandas as pd        
import sqlite3             
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'fraudTest.csv',
#  'fraudTrain.csv',
#  'fraud_data_cleaner.ipynb',
#  'fraud_detection.db']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\harsh\\OneDrive\\Desktop\\FraudDetection'

# %%
df = pd.read_csv('fraudTrain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'trans_date_trans_time',
#  'cc_num',
#  'merchant',
#  'category',
#  'amt',
#  'first',
#  'last',
#  'gender',
#  'street',
#  'city',
#  'state',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'job',
#  'dob',
#  'trans_num',
#  'unix_time',
#  'merch_lat',
#  'merch_long',
#  'is_fraud']

# %%
import sqlite3
conn = sqlite3.connect('fraud_detection.db')
cursor = conn.cursor()

# %%
df.to_sql('transactions', conn, if_exists='replace', index=False)
# Out:
# 1296675

# %%
pd.read_sql_query("SELECT * FROM transactions LIMIT 5;", conn)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
customers_df = df[['cc_num', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob']].drop_duplicates()
customers_df.head()
# Out:
#              cc_num      first     last gender                        street  \
# 0  2703186189652095   Jennifer    Banks      F                561 Perry Cove
# 1      630423337322  Stephanie     Gill      F  43039 Riley Greens Suite 393
# 2    38859492057661     Edward  Sanchez      M      594 White Dale Suite 530
# 3  3534093764340240     Jeremy    White      M   9443 Cynthia Court Apt. 038
# 4   375534208663984      Tyler   Garcia      M              408 Bradley Rest
#
#              city state    zip      lat      long  city_pop  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1          Orient    WA  99160  48.8878 -118.2105       149
# 2      Malad City    ID  83252  42.1808 -112.2620      4154
# 3         Boulder    MT  59632  46.2306 -112.1138      1939
# 4        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#                                  job         dob
# 0          Psychologist, counselling  1988-03-09
# ...

# %%
customers_df.to_sql('customers', conn, if_exists='replace', index=False)
# Out:
# 983

# %%
merchants_df = df[['merchant', 'category', 'merch_lat', 'merch_long']].drop_duplicates()
merchants_df.head()
# Out:
#                              merchant       category  merch_lat  merch_long
# 0          fraud_Rippin, Kub and Mann       misc_net  36.011293  -82.048315
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  49.159047 -118.186462
# 2                fraud_Lind-Buckridge  entertainment  43.150704 -112.154481
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport  47.034331 -112.561071
# 4                 fraud_Keeling-Crist       misc_pos  38.674999  -78.632459

# %%
merchants_df.to_sql('merchants', conn, if_exists='replace', index=False)
# Out:
# 1296675

# %%
transactions_df = df[['trans_date_trans_time', 'cc_num', 'merchant', 'amt', 'trans_num', 'unix_time', 'is_fraud']]
transactions_df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#       amt                         trans_num   unix_time  is_fraud
# 0    4.97  0b242abb623afc578575680df30655b9  1325376018         0
# 1  107.23  1f76529f8574734946361c461b024d99  1325376044         0
# 2  220.11  a1a22d70485983eac12b5b88dad1cf95  1325376051         0
# 3   45.00  6b849c168bdad6f867558c3793159a81  1325376076         0
# 4   41.96  a41d7549acf90789359a9aa5346dcb46  1325376186         0

# %%
transactions_df.to_sql('transactions_cleaned', conn, if_exists='replace', index=False)
# Out:
# 1296675

# %%
# Show tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('transactions',), ('customers',), ('merchants',), ('transactions_cleaned',)]

# %%
# Preview customer table
pd.read_sql_query("SELECT * FROM customers LIMIT 5;", conn)
# Out:
#              cc_num      first     last gender                        street  \
# 0  2703186189652095   Jennifer    Banks      F                561 Perry Cove
# 1      630423337322  Stephanie     Gill      F  43039 Riley Greens Suite 393
# 2    38859492057661     Edward  Sanchez      M      594 White Dale Suite 530
# 3  3534093764340240     Jeremy    White      M   9443 Cynthia Court Apt. 038
# 4   375534208663984      Tyler   Garcia      M              408 Bradley Rest
#
#              city state    zip      lat      long  city_pop  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1          Orient    WA  99160  48.8878 -118.2105       149
# 2      Malad City    ID  83252  42.1808 -112.2620      4154
# 3         Boulder    MT  59632  46.2306 -112.1138      1939
# 4        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#                                  job         dob
# 0          Psychologist, counselling  1988-03-09
# ...

# %%
# Preview merchant table
pd.read_sql_query("SELECT * FROM merchants LIMIT 5;", conn)
# Out:
#                              merchant       category  merch_lat  merch_long
# 0          fraud_Rippin, Kub and Mann       misc_net  36.011293  -82.048315
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  49.159047 -118.186462
# 2                fraud_Lind-Buckridge  entertainment  43.150704 -112.154481
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport  47.034331 -112.561071
# 4                 fraud_Keeling-Crist       misc_pos  38.674999  -78.632459

# %%
# Preview transaction table
pd.read_sql_query("SELECT * FROM transactions_cleaned LIMIT 5;", conn)
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#       amt                         trans_num   unix_time  is_fraud
# 0    4.97  0b242abb623afc578575680df30655b9  1325376018         0
# 1  107.23  1f76529f8574734946361c461b024d99  1325376044         0
# 2  220.11  a1a22d70485983eac12b5b88dad1cf95  1325376051         0
# 3   45.00  6b849c168bdad6f867558c3793159a81  1325376076         0
# 4   41.96  a41d7549acf90789359a9aa5346dcb46  1325376186         0

# %%
query = """
SELECT 
    t1.trans_num,
    t1.cc_num,
    t1.trans_date_trans_time,
    t1.amt,
    t2.trans_date_trans_time AS previous_time,
    ROUND((JULIANDAY(t1.trans_date_trans_time) - JULIANDAY(t2.trans_date_trans_time)) * 24 * 60, 2) AS minutes_difference
FROM transactions_cleaned t1
JOIN (
    SELECT 
        trans_num, 
        cc_num, 
        trans_date_trans_time,
        LAG(trans_date_trans_time) OVER (PARTITION BY cc_num ORDER BY trans_date_trans_time) AS previous_time
    FROM transactions_cleaned
) t2
ON t1.trans_num = t2.trans_num
WHERE 
    previous_time IS NOT NULL
    AND ROUND((JULIANDAY(t1.trans_date_trans_time) - JULIANDAY(t2.previous_time)) * 24 * 60, 2) < 2;
"""

# %%
pd.read_sql_query(query, conn)
# Out:
#                              trans_num            cc_num  \
# 0     3c6158c556727d527f8b51cc03b30236  6593250708747804
# 1     e464e694234a447e69ae2b3d4afb7804  3567879740649740
# 2     cae903dcfe6c794e9a96c38f37f68f87  2285066385084291
# 3     d0bd90cb8679739b62e47751afc88326  4836998673805450
# 4     100f6146829a593605fe199a0a0fb4d5  4998109455173950
# ...                                ...               ...
# 8109  9449bedfc7967f0bd62163b378d36060   370877495212014
# 8110  f7589169a32b5c792a5a5722d8c9b8a8   377654590313960
# 8111  43f4bfa1d82aad90aa0001eb0fe9a156     4755696071492
# 8112  858ab81586299d01ada986b519daba8c     4640395708703
# 8113  68a1da9d227e553dc8cebe0449bdc853   344342339068828
#
#      trans_date_trans_time     amt        previous_time  minutes_difference
# 0      2019-01-01 01:16:52   55.18  2019-01-01 01:16:52                 0.0
# 1      2019-01-01 01:33:52   58.79  2019-01-01 01:33:52                 0.0
# ...

# %%
cursor.execute("""
CREATE VIEW IF NOT EXISTS trans_with_location AS
SELECT 
    t.trans_num,
    t.cc_num,
    t.trans_date_trans_time,
    t.unix_time,
    m.merchant,
    m.merch_lat,
    m.merch_long
FROM transactions_cleaned t
JOIN merchants m ON t.merchant = m.merchant
""")
conn.commit()

# %%
query2 = """
WITH ordered_trans AS (
    SELECT *,
        LAG(merch_lat) OVER (PARTITION BY cc_num ORDER BY unix_time) AS prev_lat,
        LAG(merch_long) OVER (PARTITION BY cc_num ORDER BY unix_time) AS prev_long,
        LAG(unix_time) OVER (PARTITION BY cc_num ORDER BY unix_time) AS prev_unix_time
    FROM trans_with_location
),
distances AS (
    SELECT *,
        ( ( (merch_lat - prev_lat)*(merch_lat - prev_lat) + 
            (merch_long - prev_long)*(merch_long - prev_long) ) * 111 * 111 ) AS distance_km,
        (unix_time - prev_unix_time) / 3600.0 AS time_diff_hr
    FROM ordered_trans
    WHERE prev_lat IS NOT NULL AND prev_long IS NOT NULL
)
SELECT * FROM distances
WHERE distance_km / time_diff_hr > 1000;
"""

# %%
pd.read_sql_query(query2, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: database or disk is full
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 pd.read_sql_query(query2, conn)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
# ...

# %%
query3 = """
WITH avg_spend AS (
    SELECT 
        cc_num,
        AVG(amt) AS avg_amt
    FROM transactions_cleaned
    GROUP BY cc_num
)
SELECT 
    t.trans_num,
    t.cc_num,
    t.amt,
    a.avg_amt
FROM transactions_cleaned t
JOIN avg_spend a ON t.cc_num = a.cc_num
WHERE t.amt > 5 * a.avg_amt;
"""

# %%
pd.read_sql_query(query3, conn)

# %%
query4 = """
WITH category_count AS (
    SELECT cc_num, category, COUNT(*) AS cnt
    FROM transactions_cleaned t
    JOIN merchants m ON t.merchant = m.merchant
    GROUP BY cc_num, category
),
main_category AS (
    SELECT cc_num, category
    FROM (
        SELECT cc_num, category, RANK() OVER (PARTITION BY cc_num ORDER BY cnt DESC) AS rk
        FROM category_count
    ) WHERE rk = 1
)
SELECT t.trans_num, t.cc_num, m.category, mc.category AS usual_category
FROM transactions_cleaned t
JOIN merchants m ON t.merchant = m.merchant
JOIN main_category mc ON t.cc_num = mc.cc_num
WHERE m.category != mc.category;
"""

# %%
pd.read_sql_query(query4, conn)
